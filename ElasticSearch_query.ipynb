# %%
from elasticsearch import Elasticsearch
 
ES_HOST = {"host" : "localhost", "port" : 9200}
es = Elasticsearch(hosts = [ES_HOST])

res = es.search(body= {
    "query": {
        "match": {
            "text" : "Flyers"
        }
    }
})
res['hits']
# Out:
# {'total': 8,
#  'max_score': 3.968788,
#  'hits': [{'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074785238935588864',
#    '_score': 3.968788,
#    '_source': {'created_at': 'Mon Dec 17 21:55:44 +0000 2018',
#     'id': 1074785238935588864,
#     'id_str': '1074785238935588864',
#     'text': 'So..  is Flyers hockey going to be fun again?',
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 22644837,
#      'id_str': '22644837',
#      'name': 'Mike',
#      'screen_name': 'mbailey010',
#      'location': 'Pennsylvania, USA',
#      'url': None,
#      'description': 'Podcaster.  Writer. @BrotherlyPuck Follow for random dog pics.',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 372,
#      'friends_count': 588,
#      'listed_count': 2,
#      'favourites_count': 3453,
#      'statuses_count': 6183,
#      'created_at': 'Tue Mar 03 16:56:17 +0000 2009',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/965464606155124736/jdId0Ooh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/965464606155124736/jdId0Ooh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22644837/1529192561',
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [],
#      'urls': [],
#      'user_mentions': [],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545083744163'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074785111701446656',
#    '_score': 3.3194501,
#    '_source': {'created_at': 'Mon Dec 17 21:55:13 +0000 2018',
#     'id': 1074785111701446656,
#     'id_str': '1074785111701446656',
#     'text': 'The latest ATL Sports Bar! https://t.co/h1n5jfEVp5 #flyers #nhl',
#     'source': '<a href="https://paper.li" rel="nofollow">Paper.li</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 18435438,
#      'id_str': '18435438',
#      'name': 'Channel 1 Atlanta',
#      'screen_name': 'channel1atlanta',
#      'location': 'Atlanta, GA',
#      'url': None,
#      'description': '[JUST THE FACTS!] Real breaking news for Atlanta, America, and the World!',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 3526,
#      'friends_count': 4362,
#      'listed_count': 165,
#      'favourites_count': 14718,
#      'statuses_count': 334455,
#      'created_at': 'Sun Dec 28 22:17:21 +0000 2008',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': True,
#      'profile_link_color': 'A30606',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1074091637603676160/5zxtSlhT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1074091637603676160/5zxtSlhT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18435438/1544918805',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [{'text': 'flyers', 'indices': [51, 58]},
#       {'text': 'nhl', 'indices': [59, 63]}],
#      'urls': [{'url': 'https://t.co/h1n5jfEVp5',
#        'expanded_url': 'https://paper.li/channel1atlanta/1333698661?edition_id=6dee2280-0246-11e9-9722-0cc47a0d164b',
#        'display_url': 'paper.li/channel1atlant…',
#        'indices': [27, 50]}],
#      'user_mentions': [],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545083713828'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074776728118157312',
#    '_score': 3.2296002,
#    '_source': {'created_at': 'Mon Dec 17 21:21:55 +0000 2018',
#     'id': 1074776728118157312,
#     'id_str': '1074776728118157312',
#     'text': 'Hakstol fired as coach of Flyers https://t.co/quSk8pIGrd via @NHLdotcom',
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 394385099,
#      'id_str': '394385099',
#      'name': 'Bhavik Patel',
#      'screen_name': 'bhavikp27',
#      'location': None,
#      'url': None,
#      'description': 'Hockey (Boston Bruins) fan. 😀',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 759,
#      'friends_count': 1699,
#      'listed_count': 55,
#      'favourites_count': 2213,
#      'statuses_count': 56531,
#      'created_at': 'Thu Oct 20 00:21:03 +0000 2011',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '981CEB',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_tile': False,
#      'profile_link_color': 'FF691F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'F6FFD1',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/877543598526406656/ZIL77wiE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877543598526406656/ZIL77wiE_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/394385099/1498058073',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [],
#      'urls': [{'url': 'https://t.co/quSk8pIGrd',
#        'expanded_url': 'https://www.nhl.com/news/dave-hakstol-fired-as-coach-of-philadelphia-flyers/c-303022652?tcid=tw_news_content_id',
#        'display_url': 'nhl.com/news/dave-haks…',
#        'indices': [33, 56]}],
#      'user_mentions': [{'screen_name': 'NHLdotcom',
#        'name': 'NHL.com',
#        'id': 1037738468972154880,
#        'id_str': '1037738468972154880',
#        'indices': [61, 71]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545081715026'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074785011566489600',
#    '_score': 3.066106,
#    '_source': {'created_at': 'Mon Dec 17 21:54:49 +0000 2018',
#     'id': 1074785011566489600,
#     'id_str': '1074785011566489600',
#     'text': 'RT @WHLsilvertips: OFFICIAL // Carter Hart has been called up to the NHL &amp; Philadelphia Flyers\n\n#LetsGoTips | #Number1HockeyBoy \n\nNews: htt…',
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2301804010,
#      'id_str': '2301804010',
#      'name': 'Joshua Bright',
#      'screen_name': 'Ponti_flex_',
#      'location': 'Los Angeles, CA',
#      'url': 'http://PhillyIsFlyer.com',
#      'description': None,
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 1245,
#      'friends_count': 773,
#      'listed_count': 43,
#      'favourites_count': 12654,
#      'statuses_count': 41673,
#      'created_at': 'Fri Jan 24 16:58:18 +0000 2014',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1073309150510227458/wnR6e3_l_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1073309150510227458/wnR6e3_l_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2301804010/1522610714',
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Dec 17 21:08:23 +0000 2018',
#      'id': 1074773324520087552,
#      'id_str': '1074773324520087552',
#      'text': 'OFFICIAL // Carter Hart has been called up to the NHL &amp; Philadelphia Flyers\n\n#LetsGoTips | #Number1HockeyBoy \n\nNews… https://t.co/jPlpOGSZ4i',
#      'display_text_range': [0, 140],
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'truncated': True,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 27987121,
#       'id_str': '27987121',
#       'name': 'Everett Silvertips',
#       'screen_name': 'WHLsilvertips',
#       'location': 'Everett, WA',
#       'url': 'http://www.everettsilvertips.com/tickets',
#       'description': 'Official account. Defending Western Conference champs. ORDER TICKETS // (425) 252-5100 or click link 👇 #SilvertipCountry',
#       'translator_type': 'none',
#       'protected': False,
#       'verified': True,
#       'followers_count': 21273,
#       'friends_count': 1104,
#       'listed_count': 353,
#       'favourites_count': 2588,
#       'statuses_count': 26203,
#       'created_at': 'Tue Mar 31 22:58:40 +0000 2009',
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'profile_background_color': '0D6339',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_link_color': '0D6339',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': 'E6E6E6',
#       'profile_text_color': '0D6339',
#       'profile_use_background_image': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1073701714929213440/INmsi1mJ_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1073701714929213440/INmsi1mJ_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27987121/1539498632',
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'extended_tweet': {'full_text': 'OFFICIAL // Carter Hart has been called up to the NHL &amp; Philadelphia Flyers\n\n#LetsGoTips | #Number1HockeyBoy \n\nNews: https://t.co/NxT2HRoCDa https://t.co/RL6Be7kS9D',
#       'display_text_range': [0, 144],
#       'entities': {'hashtags': [{'text': 'LetsGoTips', 'indices': [81, 92]},
#         {'text': 'Number1HockeyBoy', 'indices': [95, 112]}],
#        'urls': [{'url': 'https://t.co/NxT2HRoCDa',
#          'expanded_url': 'http://everettsilvertips.com/article/called-up-carter-hart-to-the-nhl-philadelphia-flyers',
#          'display_url': 'everettsilvertips.com/article/called…',
#          'indices': [121, 144]}],
#        'user_mentions': [],
#        'symbols': [],
#        'media': [{'id': 1074773038283907072,
#          'id_str': '1074773038283907072',
#          'indices': [145, 168],
#          'media_url': 'http://pbs.twimg.com/media/DupcYkkUYAANuCy.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/DupcYkkUYAANuCy.jpg',
#          'url': 'https://t.co/RL6Be7kS9D',
#          'display_url': 'pic.twitter.com/RL6Be7kS9D',
#          'expanded_url': 'https://twitter.com/WHLsilvertips/status/1074773324520087552/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#           'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#           'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#       'extended_entities': {'media': [{'id': 1074773038283907072,
#          'id_str': '1074773038283907072',
#          'indices': [145, 168],
#          'media_url': 'http://pbs.twimg.com/media/DupcYkkUYAANuCy.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/DupcYkkUYAANuCy.jpg',
#          'url': 'https://t.co/RL6Be7kS9D',
#          'display_url': 'pic.twitter.com/RL6Be7kS9D',
#          'expanded_url': 'https://twitter.com/WHLsilvertips/status/1074773324520087552/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'large': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#           'medium': {'w': 1080, 'h': 1080, 'resize': 'fit'},
#           'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]}},
#      'quote_count': 3,
#      'reply_count': 2,
#      'retweet_count': 20,
#      'favorite_count': 61,
#      'entities': {'hashtags': [{'text': 'LetsGoTips', 'indices': [81, 92]},
#        {'text': 'Number1HockeyBoy', 'indices': [95, 112]}],
#       'urls': [{'url': 'https://t.co/jPlpOGSZ4i',
#         'expanded_url': 'https://twitter.com/i/web/status/1074773324520087552',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [121, 144]}],
#       'user_mentions': [],
#       'symbols': []},
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'filter_level': 'low',
#      'lang': 'en'},
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [{'text': 'LetsGoTips', 'indices': [100, 111]},
#       {'text': 'Number1HockeyBoy', 'indices': [114, 131]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'WHLsilvertips',
#        'name': 'Everett Silvertips',
#        'id': 27987121,
#        'id_str': '27987121',
#        'indices': [3, 17]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545083689954'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074785041832497154',
#    '_score': 3.0308685,
#    '_source': {'created_at': 'Mon Dec 17 21:54:57 +0000 2018',
#     'id': 1074785041832497154,
#     'id_str': '1074785041832497154',
#     'text': 'RT @NHLFlyers: The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony S…',
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 222846092,
#      'id_str': '222846092',
#      'name': 'tatooed goalie dad #31🇵🇹🇨🇦',
#      'screen_name': 'sandropacheco71',
#      'location': 'Stouffville, Canada',
#      'url': None,
#      'description': 'Cancer Survivor. Philadelphia Flyers, Lindros fanatic. Proud hockey goalie dad. Ronaldo, Jays, Bills, Raptors, fan. Proud Açoriano (Portuguese) I follow back.',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 13555,
#      'friends_count': 12585,
#      'listed_count': 73,
#      'favourites_count': 8704,
#      'statuses_count': 35928,
#      'created_at': 'Sat Dec 04 16:42:44 +0000 2010',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '1F1C1A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_link_color': '822FED',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/506187223025614849/sMWce05d_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/506187223025614849/sMWce05d_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/222846092/1411608845',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Dec 17 16:16:25 +0000 2018',
#      'id': 1074699846861369349,
#      'id_str': '1074699846861369349',
#      'text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender… https://t.co/KP44hrJQfU',
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'truncated': True,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 19618527,
#       'id_str': '19618527',
#       'name': 'Philadelphia Flyers',
#       'screen_name': 'NHLFlyers',
#       'location': 'Philadelphia, PA',
#       'url': 'http://www.philadelphiaflyers.com',
#       'description': None,
#       'translator_type': 'none',
#       'protected': False,
#       'verified': True,
#       'followers_count': 1550871,
#       'friends_count': 276,
#       'listed_count': 6052,
#       'favourites_count': 2673,
#       'statuses_count': 37278,
#       'created_at': 'Tue Jan 27 21:41:32 +0000 2009',
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_link_color': 'F57936',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDFFCC',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19618527/1544192282',
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'extended_tweet': {'full_text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony Stolarz on Injured Reserve. https://t.co/P6asgsZ9Xg',
#       'display_text_range': [0, 174],
#       'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#        'urls': [{'url': 'https://t.co/P6asgsZ9Xg',
#          'expanded_url': 'https://www.nhl.com/flyers/news/flyers-recall-carter-hart-from-phantoms--philadelphia-flyers/c-303017766',
#          'display_url': 'nhl.com/flyers/news/fl…',
#          'indices': [151, 174]}],
#        'user_mentions': [{'screen_name': 'LVPhantoms',
#          'name': 'LehighValleyPhantoms',
#          'id': 329335239,
#          'id_str': '329335239',
#          'indices': [58, 69]}],
#        'symbols': []}},
#      'quote_count': 726,
#      'reply_count': 350,
#      'retweet_count': 858,
#      'favorite_count': 2477,
#      'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#       'urls': [{'url': 'https://t.co/KP44hrJQfU',
#         'expanded_url': 'https://twitter.com/i/web/status/1074699846861369349',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}],
#       'user_mentions': [{'screen_name': 'LVPhantoms',
#         'name': 'LehighValleyPhantoms',
#         'id': 329335239,
#         'id_str': '329335239',
#         'indices': [58, 69]}],
#       'symbols': []},
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'filter_level': 'low',
#      'lang': 'en'},
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [{'text': 'Flyers', 'indices': [19, 26]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'NHLFlyers',
#        'name': 'Philadelphia Flyers',
#        'id': 19618527,
#        'id_str': '19618527',
#        'indices': [3, 13]},
#       {'screen_name': 'LVPhantoms',
#        'name': 'LehighValleyPhantoms',
#        'id': 329335239,
#        'id_str': '329335239',
#        'indices': [73, 84]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545083697170'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074777175096782849',
#    '_score': 2.9381099,
#    '_source': {'created_at': 'Mon Dec 17 21:23:41 +0000 2018',
#     'id': 1074777175096782849,
#     'id_str': '1074777175096782849',
#     'text': 'RT @NHLFlyers: The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony S…',
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1514691913,
#      'id_str': '1514691913',
#      'name': 'raymond kuhn',
#      'screen_name': 'Philly825Rayin',
#      'location': None,
#      'url': None,
#      'description': None,
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 16,
#      'friends_count': 34,
#      'listed_count': 0,
#      'favourites_count': 2182,
#      'statuses_count': 381,
#      'created_at': 'Thu Jun 13 22:52:57 +0000 2013',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/444907069876236288/Aw-CAk_B_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/444907069876236288/Aw-CAk_B_normal.jpeg',
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Dec 17 16:16:25 +0000 2018',
#      'id': 1074699846861369349,
#      'id_str': '1074699846861369349',
#      'text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender… https://t.co/KP44hrJQfU',
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'truncated': True,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 19618527,
#       'id_str': '19618527',
#       'name': 'Philadelphia Flyers',
#       'screen_name': 'NHLFlyers',
#       'location': 'Philadelphia, PA',
#       'url': 'http://www.philadelphiaflyers.com',
#       'description': None,
#       'translator_type': 'none',
#       'protected': False,
#       'verified': True,
#       'followers_count': 1550846,
#       'friends_count': 276,
#       'listed_count': 6051,
#       'favourites_count': 2673,
#       'statuses_count': 37277,
#       'created_at': 'Tue Jan 27 21:41:32 +0000 2009',
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_link_color': 'F57936',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDFFCC',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19618527/1544192282',
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'extended_tweet': {'full_text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony Stolarz on Injured Reserve. https://t.co/P6asgsZ9Xg',
#       'display_text_range': [0, 174],
#       'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#        'urls': [{'url': 'https://t.co/P6asgsZ9Xg',
#          'expanded_url': 'https://www.nhl.com/flyers/news/flyers-recall-carter-hart-from-phantoms--philadelphia-flyers/c-303017766',
#          'display_url': 'nhl.com/flyers/news/fl…',
#          'indices': [151, 174]}],
#        'user_mentions': [{'screen_name': 'LVPhantoms',
#          'name': 'LehighValleyPhantoms',
#          'id': 329335239,
#          'id_str': '329335239',
#          'indices': [58, 69]}],
#        'symbols': []}},
#      'quote_count': 723,
#      'reply_count': 346,
#      'retweet_count': 844,
#      'favorite_count': 2421,
#      'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#       'urls': [{'url': 'https://t.co/KP44hrJQfU',
#         'expanded_url': 'https://twitter.com/i/web/status/1074699846861369349',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}],
#       'user_mentions': [{'screen_name': 'LVPhantoms',
#         'name': 'LehighValleyPhantoms',
#         'id': 329335239,
#         'id_str': '329335239',
#         'indices': [58, 69]}],
#       'symbols': []},
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'filter_level': 'low',
#      'lang': 'en'},
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [{'text': 'Flyers', 'indices': [19, 26]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'NHLFlyers',
#        'name': 'Philadelphia Flyers',
#        'id': 19618527,
#        'id_str': '19618527',
#        'indices': [3, 13]},
#       {'screen_name': 'LVPhantoms',
#        'name': 'LehighValleyPhantoms',
#        'id': 329335239,
#        'id_str': '329335239',
#        'indices': [73, 84]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545081821594'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074785158614605824',
#    '_score': 2.8775952,
#    '_source': {'created_at': 'Mon Dec 17 21:55:25 +0000 2018',
#     'id': 1074785158614605824,
#     'id_str': '1074785158614605824',
#     'text': "@JameyBaskow I mean, he can't be much worse than the current Flyers goaltending situation. It will be good for him… https://t.co/kdhNV5HELm",
#     'display_text_range': [13, 140],
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'truncated': True,
#     'in_reply_to_status_id': 1074784344076640256,
#     'in_reply_to_status_id_str': '1074784344076640256',
#     'in_reply_to_user_id': 812371848151252993,
#     'in_reply_to_user_id_str': '812371848151252993',
#     'in_reply_to_screen_name': 'JameyBaskow',
#     'user': {'id': 383625197,
#      'id_str': '383625197',
#      'name': 'Zack Steffel',
#      'screen_name': 'Zackzerz',
#      'location': None,
#      'url': None,
#      'description': None,
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 158,
#      'friends_count': 270,
#      'listed_count': 7,
#      'favourites_count': 22149,
#      'statuses_count': 6178,
#      'created_at': 'Sun Oct 02 06:37:13 +0000 2011',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1751013889/image_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1751013889/image_normal.jpg',
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'extended_tweet': {'full_text': "@JameyBaskow I mean, he can't be much worse than the current Flyers goaltending situation. It will be good for him to get some NHL playing time. He did seem to be better than Lyon over his past two weeks or so. I'm excited again, Jamey!",
#      'display_text_range': [13, 236],
#      'entities': {'hashtags': [],
#       'urls': [],
#       'user_mentions': [{'screen_name': 'JameyBaskow',
#         'name': 'Jamey Baskow',
#         'id': 812371848151252993,
#         'id_str': '812371848151252993',
#         'indices': [0, 12]}],
#       'symbols': []}},
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [],
#      'urls': [{'url': 'https://t.co/kdhNV5HELm',
#        'expanded_url': 'https://twitter.com/i/web/status/1074785158614605824',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}],
#      'user_mentions': [{'screen_name': 'JameyBaskow',
#        'name': 'Jamey Baskow',
#        'id': 812371848151252993,
#        'id_str': '812371848151252993',
#        'indices': [0, 12]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545083725013'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074776722871123968',
#    '_score': 2.541638,
#    '_source': {'created_at': 'Mon Dec 17 21:21:53 +0000 2018',
#     'id': 1074776722871123968,
#     'id_str': '1074776722871123968',
#     'text': 'RT @NHLFlyers: The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony S…',
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1021139648,
#      'id_str': '1021139648',
#      'name': 'OPWchris',
#      'screen_name': 'OPWchris',
#      'location': 'Parts Unknown',
#      'url': 'http://www.OPWrestling.com',
#      'description': '@OnPointWrestlin staff. Former WSU/CZW staff. I play in traffic. @ScaresThatCare NJ State Rep. Coffee fiend. @RowanRadio alumni & fill in air talent.',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 961,
#      'friends_count': 1875,
#      'listed_count': 47,
#      'favourites_count': 6776,
#      'statuses_count': 18958,
#      'created_at': 'Wed Dec 19 02:25:49 +0000 2012',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_link_color': '000088',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/946298978248695809/1Ire9zpr_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946298978248695809/1Ire9zpr_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021139648/1446786885',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Dec 17 16:16:25 +0000 2018',
#      'id': 1074699846861369349,
#      'id_str': '1074699846861369349',
#      'text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender… https://t.co/KP44hrJQfU',
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'truncated': True,
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 19618527,
#       'id_str': '19618527',
#       'name': 'Philadelphia Flyers',
#       'screen_name': 'NHLFlyers',
#       'location': 'Philadelphia, PA',
#       'url': 'http://www.philadelphiaflyers.com',
#       'description': None,
#       'translator_type': 'none',
#       'protected': False,
#       'verified': True,
#       'followers_count': 1550847,
#       'friends_count': 276,
#       'listed_count': 6051,
#       'favourites_count': 2673,
#       'statuses_count': 37277,
#       'created_at': 'Tue Jan 27 21:41:32 +0000 2009',
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'lang': 'en',
#       'contributors_enabled': False,
#       'is_translator': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_link_color': 'F57936',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDFFCC',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071046104035266560/J2Fe9oSh_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19618527/1544192282',
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'extended_tweet': {'full_text': 'The #Flyers have recalled goaltender Carter Hart from the @LVPhantoms. In addition, the club has placed goaltender Anthony Stolarz on Injured Reserve. https://t.co/P6asgsZ9Xg',
#       'display_text_range': [0, 174],
#       'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#        'urls': [{'url': 'https://t.co/P6asgsZ9Xg',
#          'expanded_url': 'https://www.nhl.com/flyers/news/flyers-recall-carter-hart-from-phantoms--philadelphia-flyers/c-303017766',
#          'display_url': 'nhl.com/flyers/news/fl…',
#          'indices': [151, 174]}],
#        'user_mentions': [{'screen_name': 'LVPhantoms',
#          'name': 'LehighValleyPhantoms',
#          'id': 329335239,
#          'id_str': '329335239',
#          'indices': [58, 69]}],
#        'symbols': []}},
#      'quote_count': 723,
#      'reply_count': 346,
#      'retweet_count': 843,
#      'favorite_count': 2418,
#      'entities': {'hashtags': [{'text': 'Flyers', 'indices': [4, 11]}],
#       'urls': [{'url': 'https://t.co/KP44hrJQfU',
#         'expanded_url': 'https://twitter.com/i/web/status/1074699846861369349',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}],
#       'user_mentions': [{'screen_name': 'LVPhantoms',
#         'name': 'LehighValleyPhantoms',
#         'id': 329335239,
#         'id_str': '329335239',
#         'indices': [58, 69]}],
#       'symbols': []},
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'filter_level': 'low',
#      'lang': 'en'},
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [{'text': 'Flyers', 'indices': [19, 26]}],
#      'urls': [],
#      'user_mentions': [{'screen_name': 'NHLFlyers',
#        'name': 'Philadelphia Flyers',
#        'id': 19618527,
#        'id_str': '19618527',
#        'indices': [3, 13]},
#       {'screen_name': 'LVPhantoms',
#        'name': 'LehighValleyPhantoms',
#        'id': 329335239,
#        'id_str': '329335239',
#        'indices': [73, 84]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545081713775'}}]}

# %%
res2 = es.search(body= {
    "query": {
        "match": {
            "text" : "Hakstol"
        }
    }
})
res2['hits']
# Out:
# {'total': 2,
#  'max_score': 4.236556,
#  'hits': [{'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074776728118157312',
#    '_score': 4.236556,
#    '_source': {'created_at': 'Mon Dec 17 21:21:55 +0000 2018',
#     'id': 1074776728118157312,
#     'id_str': '1074776728118157312',
#     'text': 'Hakstol fired as coach of Flyers https://t.co/quSk8pIGrd via @NHLdotcom',
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'truncated': False,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 394385099,
#      'id_str': '394385099',
#      'name': 'Bhavik Patel',
#      'screen_name': 'bhavikp27',
#      'location': None,
#      'url': None,
#      'description': 'Hockey (Boston Bruins) fan. 😀',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 759,
#      'friends_count': 1699,
#      'listed_count': 55,
#      'favourites_count': 2213,
#      'statuses_count': 56531,
#      'created_at': 'Thu Oct 20 00:21:03 +0000 2011',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': '981CEB',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_tile': False,
#      'profile_link_color': 'FF691F',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'F6FFD1',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/877543598526406656/ZIL77wiE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877543598526406656/ZIL77wiE_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/394385099/1498058073',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [],
#      'urls': [{'url': 'https://t.co/quSk8pIGrd',
#        'expanded_url': 'https://www.nhl.com/news/dave-hakstol-fired-as-coach-of-philadelphia-flyers/c-303022652?tcid=tw_news_content_id',
#        'display_url': 'nhl.com/news/dave-haks…',
#        'indices': [33, 56]}],
#      'user_mentions': [{'screen_name': 'NHLdotcom',
#        'name': 'NHL.com',
#        'id': 1037738468972154880,
#        'id_str': '1037738468972154880',
#        'indices': [61, 71]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545081715026'}},
#   {'_index': 'hockey_tweets',
#    '_type': 'tweets',
#    '_id': '1074769029049520128',
#    '_score': 2.7680392,
#    '_source': {'created_at': 'Mon Dec 17 20:51:19 +0000 2018',
#     'id': 1074769029049520128,
#     'id_str': '1074769029049520128',
#     'text': '@Kurt_BSH Wish Hakstol nothing but the best in the future. At a hockey level I’m glad he’s gone. But at a personal… https://t.co/Aza3pvmPVE',
#     'display_text_range': [10, 140],
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'truncated': True,
#     'in_reply_to_status_id': 1074767695474769923,
#     'in_reply_to_status_id_str': '1074767695474769923',
#     'in_reply_to_user_id': 564104893,
#     'in_reply_to_user_id_str': '564104893',
#     'in_reply_to_screen_name': 'Kurt_BSH',
#     'user': {'id': 476488285,
#      'id_str': '476488285',
#      'name': 'Flyer fan Phil',
#      'screen_name': 'PhilGarrett12',
#      'location': 'St. Louis, MO',
#      'url': None,
#      'description': 'Hang tough. Do your best everyday.',
#      'translator_type': 'none',
#      'protected': False,
#      'verified': False,
#      'followers_count': 427,
#      'friends_count': 799,
#      'listed_count': 3,
#      'favourites_count': 7022,
#      'statuses_count': 10616,
#      'created_at': 'Sat Jan 28 05:42:06 +0000 2012',
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'profile_background_color': 'FCFCF7',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_link_color': '0A0A01',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1074707346822230016/GxXzBTTI_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1074707346822230016/GxXzBTTI_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/476488285/1540129518',
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'extended_tweet': {'full_text': '@Kurt_BSH Wish Hakstol nothing but the best in the future. At a hockey level I’m glad he’s gone. But at a personal level you hate to see anybody lose their job.',
#      'display_text_range': [10, 160],
#      'entities': {'hashtags': [],
#       'urls': [],
#       'user_mentions': [{'screen_name': 'Kurt_BSH',
#         'name': 'Kurt',
#         'id': 564104893,
#         'id_str': '564104893',
#         'indices': [0, 9]}],
#       'symbols': []}},
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'entities': {'hashtags': [],
#      'urls': [{'url': 'https://t.co/Aza3pvmPVE',
#        'expanded_url': 'https://twitter.com/i/web/status/1074769029049520128',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}],
#      'user_mentions': [{'screen_name': 'Kurt_BSH',
#        'name': 'Kurt',
#        'id': 564104893,
#        'id_str': '564104893',
#        'indices': [0, 9]}],
#      'symbols': []},
#     'favorited': False,
#     'retweeted': False,
#     'filter_level': 'low',
#     'lang': 'en',
#     'timestamp_ms': '1545079879425'}}]}
